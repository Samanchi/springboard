# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %%
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          91449            50460.2    93284.5    64958.1
# 2 1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3 1995-03-01        79120.7              51269    92247.5    64367.5
# 4 1995-04-01        77101.2            53133.5    90762.9    64277.7
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
# 1    71306.6    81671.5     120933    69158.2    79885.9  ...    43958.5
# 2    72022.3    81657.6     119509    68951.1    80897.1  ...    43925.4
# 3    72015.8    81449.3     120282    68712.4    81379.9  ...    44434.9
# 4    72965.6    81124.4     120098      68610    82188.9  ...    44267.8
#
#   YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# ...

# %%
properties.shape
# Out:
# (311, 49)

# %%
properties.index
# Out:
# RangeIndex(start=0, stop=311, step=1)

# %%
properties_transpose=properties.T

# %%
properties_transpose.index
# Out:
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %%
properties_transpose.head()
# Out:
#                           0                    1                    2    \
# Unnamed: 0                NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London      E09000001                91449              82202.8
# Barking & Dagenham  E09000002              50460.2              51085.8
# Barnet              E09000003              93284.5              93190.2
# Bexley              E09000004              64958.1              64787.9
#
#                                     3                    4    \
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00
# City of London                  79120.7              77101.2
# Barking & Dagenham                51269              53133.5
# Barnet                          92247.5              90762.9
# Bexley                          64367.5              64277.7
#
#                                     5                    6    \
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00
# ...

# %%
properties_transpose=properties_transpose.reset_index()
properties_transpose.head()
# Out:
# Unnamed: 0               index        NaN  1995-01-01 00:00:00  \
# 0                   Unnamed: 0        NaT  1995-01-01 00:00:00
# 1               City of London  E09000001                91449
# 2           Barking & Dagenham  E09000002              50460.2
# 3                       Barnet  E09000003              93284.5
# 4                       Bexley  E09000004              64958.1
#
# Unnamed: 0  1995-02-01 00:00:00  1995-03-01 00:00:00  1995-04-01 00:00:00  \
# 0           1995-02-01 00:00:00  1995-03-01 00:00:00  1995-04-01 00:00:00
# 1                       82202.8              79120.7              77101.2
# 2                       51085.8                51269              53133.5
# 3                       93190.2              92247.5              90762.9
# 4                       64787.9              64367.5              64277.7
#
# Unnamed: 0  1995-05-01 00:00:00  1995-06-01 00:00:00  1995-07-01 00:00:00  \
# ...

# %%
properties_transpose.columns=properties_transpose.iloc[0]

# %%
properties_transpose.head()
# Out:
# 0          Unnamed: 0        NaN  1995-01-01 00:00:00  1995-02-01 00:00:00  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001                91449              82202.8
# 2  Barking & Dagenham  E09000002              50460.2              51085.8
# 3              Barnet  E09000003              93284.5              93190.2
# 4              Bexley  E09000004              64958.1              64787.9
#
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1              79120.7              77101.2              84409.1
# 2                51269              53133.5              53042.2
# 3              92247.5              90762.9                90258
# 4              64367.5              64277.7              63997.1
#
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...  \
# ...

# %%
properties_transpose=properties_transpose.drop(0)

# %%
properties_transpose.head()
# Out:
# 0          Unnamed: 0        NaN 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001               91449             82202.8
# 2  Barking & Dagenham  E09000002             50460.2             51085.8
# 3              Barnet  E09000003             93284.5             93190.2
# 4              Bexley  E09000004             64958.1             64787.9
# 5               Brent  E09000005             71306.6             72022.3
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1             79120.7             77101.2             84409.1
# 2               51269             53133.5             53042.2
# 3             92247.5             90762.9               90258
# 4             64367.5             64277.7             63997.1
# 5             72015.8             72965.6               73704
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1             94900.5              110128              112329  ...
# ...

# %%
properties_transpose=properties_transpose.rename(columns={'Unnamed: 0':'London_Borough',pd.NaT:'ID'})

# %%
properties_transpose.head()
# Out:
# 0      London_Borough         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001               91449             82202.8
# 2  Barking & Dagenham  E09000002             50460.2             51085.8
# 3              Barnet  E09000003             93284.5             93190.2
# 4              Bexley  E09000004             64958.1             64787.9
# 5               Brent  E09000005             71306.6             72022.3
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1             79120.7             77101.2             84409.1
# 2               51269             53133.5             53042.2
# 3             92247.5             90762.9               90258
# 4             64367.5             64277.7             63997.1
# 5             72015.8             72965.6               73704
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1             94900.5              110128              112329  ...
# ...

# %%
clean_properties=pd.melt(properties_transpose, id_vars=['London_Borough','ID'])

# %%
clean_properties.count()
# Out:
# London_Borough    14880
# ID                13950
# 0                 14880
# value             13950
# dtype: int64

# %%
clean_properties=clean_properties.rename(columns={0:'Month','value':'Average_price'})

# %%
clean_properties.shape
# Out:
# (14880, 4)

# %%
clean_properties.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_price             object
# dtype: object

# %%
clean_properties['Average_price']=pd.to_numeric(clean_properties['Average_price'])

# %%
clean_properties.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_price            float64
# dtype: object

# %%
clean_properties.count()
# Out:
# London_Borough    14880
# ID                13950
# Month             14880
# Average_price     13950
# dtype: int64

# %%
clean_properties['London_Borough'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Unnamed: 34',
#        'Inner London', 'Outer London', 'Unnamed: 37', 'NORTH EAST',
#        'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
#        'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',
#        'SOUTH WEST', 'Unnamed: 47', 'England'], dtype=object)

# %%
clean_properties[clean_properties['London_Borough']=='Unnamed: 34']
# Out:
#       London_Borough   ID      Month  Average_price
# 33       Unnamed: 34  NaN 1995-01-01            NaN
# 81       Unnamed: 34  NaN 1995-02-01            NaN
# 129      Unnamed: 34  NaN 1995-03-01            NaN
# 177      Unnamed: 34  NaN 1995-04-01            NaN
# 225      Unnamed: 34  NaN 1995-05-01            NaN
# ...              ...  ...        ...            ...
# 14673    Unnamed: 34  NaN 2020-06-01            NaN
# 14721    Unnamed: 34  NaN 2020-07-01            NaN
# 14769    Unnamed: 34  NaN 2020-08-01            NaN
# 14817    Unnamed: 34  NaN 2020-09-01            NaN
# 14865    Unnamed: 34  NaN 2020-10-01            NaN
#
# [310 rows x 4 columns]

# %%
clean_properties[clean_properties['London_Borough']=='Unnamed: 37']
# Out:
#       London_Borough   ID      Month  Average_price
# 36       Unnamed: 37  NaN 1995-01-01            NaN
# 84       Unnamed: 37  NaN 1995-02-01            NaN
# 132      Unnamed: 37  NaN 1995-03-01            NaN
# 180      Unnamed: 37  NaN 1995-04-01            NaN
# 228      Unnamed: 37  NaN 1995-05-01            NaN
# ...              ...  ...        ...            ...
# 14676    Unnamed: 37  NaN 2020-06-01            NaN
# 14724    Unnamed: 37  NaN 2020-07-01            NaN
# 14772    Unnamed: 37  NaN 2020-08-01            NaN
# 14820    Unnamed: 37  NaN 2020-09-01            NaN
# 14868    Unnamed: 37  NaN 2020-10-01            NaN
#
# [310 rows x 4 columns]

# %%
clean_properties[clean_properties['London_Borough']=='Unnamed: 47']
# Out:
#       London_Borough   ID      Month  Average_price
# 46       Unnamed: 47  NaN 1995-01-01            NaN
# 94       Unnamed: 47  NaN 1995-02-01            NaN
# 142      Unnamed: 47  NaN 1995-03-01            NaN
# 190      Unnamed: 47  NaN 1995-04-01            NaN
# 238      Unnamed: 47  NaN 1995-05-01            NaN
# ...              ...  ...        ...            ...
# 14686    Unnamed: 47  NaN 2020-06-01            NaN
# 14734    Unnamed: 47  NaN 2020-07-01            NaN
# 14782    Unnamed: 47  NaN 2020-08-01            NaN
# 14830    Unnamed: 47  NaN 2020-09-01            NaN
# 14878    Unnamed: 47  NaN 2020-10-01            NaN
#
# [310 rows x 4 columns]

# %%
clean_properties[clean_properties['ID'].isna()]
# Out:
#       London_Borough   ID      Month  Average_price
# 33       Unnamed: 34  NaN 1995-01-01            NaN
# 36       Unnamed: 37  NaN 1995-01-01            NaN
# 46       Unnamed: 47  NaN 1995-01-01            NaN
# 81       Unnamed: 34  NaN 1995-02-01            NaN
# 84       Unnamed: 37  NaN 1995-02-01            NaN
# ...              ...  ...        ...            ...
# 14820    Unnamed: 37  NaN 2020-09-01            NaN
# 14830    Unnamed: 47  NaN 2020-09-01            NaN
# 14865    Unnamed: 34  NaN 2020-10-01            NaN
# 14868    Unnamed: 37  NaN 2020-10-01            NaN
# 14878    Unnamed: 47  NaN 2020-10-01            NaN
#
# [930 rows x 4 columns]

# %%
NanFree=clean_properties[clean_properties['Average_price'].notna()]

# %%
NanFree.count()
# Out:
# London_Borough    13950
# ID                13950
# Month             13950
# Average_price     13950
# dtype: int64

# %%
NanFree.head()
# Out:
#        London_Borough         ID      Month  Average_price
# 0      City of London  E09000001 1995-01-01    91448.98487
# 1  Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 2              Barnet  E09000003 1995-01-01    93284.51832
# 3              Bexley  E09000004 1995-01-01    64958.09036
# 4               Brent  E09000005 1995-01-01    71306.56698

# %%
NanFree['London_Borough'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Inner London',
#        'Outer London', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'England'], dtype=object)

# %%
print(clean_properties.shape)
print(NanFree.shape)
# Out:
# (14880, 4)
# (13950, 4)

# %%
NanFree.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_price            float64
# dtype: object

# %%
England_prices=NanFree[NanFree['London_Borough']=='England']

# %%
England_prices.plot(kind='line',x='Month',y='Average_price')

# %%
NanFree['Year']=NanFree['Month'].apply(lambda t:t.year)
NanFree.head()
# Out:
# /Users/apple/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        London_Borough         ID      Month  Average_price  Year
# 0      City of London  E09000001 1995-01-01    91448.98487  1995
# 1  Barking & Dagenham  E09000002 1995-01-01    50460.22660  1995
# 2              Barnet  E09000003 1995-01-01    93284.51832  1995
# 3              Bexley  E09000004 1995-01-01    64958.09036  1995
# 4               Brent  E09000005 1995-01-01    71306.56698  1995

# %%
NanMean=NanFree.groupby(by=['London_Borough','Year']).mean()

# %%
NanMean.sample(15)
# Out:
#             London_Borough  Year  Average_price
# 100                  Brent  2017  487703.754375
# 818                 Newham  2007  226388.606775
# 517             Hillingdon  2018  410266.079010
# 971              Southwark  2004  216903.918592
# 886   Richmond upon Thames  1997  136656.271017
# 718               Lewisham  2011  228017.407042
# 944             SOUTH WEST  2003  149060.437417
# 1155    YORKS & THE HUMBER  2006  136883.440242
# 389                Hackney  2020  576915.898390
# 406   Hammersmith & Fulham  2011  518573.673433
# 1106            Wandsworth  2009  340372.939092
# 469               Havering  1996   69347.956902
# 533               Hounslow  2008  262945.495542
# 750                 Merton  2017  512185.807217
# 851           Outer London  2014  328554.505275

# %%
NanMean=NanMean.reset_index()

# %%
NanMean.head()
# Out:
#        London_Borough  Year  Average_price
# 0  Barking & Dagenham  1995   51817.969390
# 1  Barking & Dagenham  1996   51718.192690
# 2  Barking & Dagenham  1997   55974.262309
# 3  Barking & Dagenham  1998   60285.821083
# 4  Barking & Dagenham  1999   65320.934441

# %%
def price_ratio(d):
    y2000=float(d['Average_price'] [d['Year']==2000])
    
    y2020=float(d['Average_price'] [d['Year']==2020])
    ratio=[y2020/y2000]
    return ratio

# %%
price_ratio(NanMean[NanMean['London_Borough']=='Barking & Dagenham'])
# Out:
# [3.8822006498501396]

# %%
final={}

# %%
for ratio in NanMean['London_Borough'].unique():
    borough=NanMean[NanMean['London_Borough']== ratio]
    final[ratio]=price_ratio(borough)
print(final)
# Out:
# {'Barking & Dagenham': [3.8822006498501396], 'Barnet': [3.1281943834256345], 'Bexley': [3.3119575396689847], 'Brent': [3.42239050954264], 'Bromley': [2.9478500991341745], 'Camden': [3.4048800282587637], 'City of London': [3.7223735268790157], 'Croydon': [3.152070292004326], 'EAST MIDLANDS': [3.197331244211788], 'EAST OF ENGLAND': [3.2128970197448496], 'Ealing': [3.14049213936213], 'Enfield': [3.2255307214261055], 'England': [3.1001550439259904], 'Greenwich': [3.593289964718748], 'Hackney': [4.3466189899176095], 'Hammersmith & Fulham': [2.887166758952764], 'Haringey': [3.8022668449313515], 'Harrow': [2.951549551636239], 'Havering': [3.373597623141555], 'Hillingdon': [3.116429479111781], 'Hounslow': [2.9889312748819803], 'Inner London': [3.6454432655336846], 'Islington': [3.4440596024856305], 'Kensington & Chelsea': [3.505896893496996], 'Kingston upon Thames': [3.0301413022021375], 'LONDON': [3.395108703230086], 'Lambeth': [3.5519971794795544], 'Lewisham': [3.9335753955484325], 'Merton
# ...

# %%
df=pd.DataFrame(final)

# %%
df_tanspose=df.T

# %%
df_tanspose.shape
# Out:
# (45, 1)

# %%
df_tanspose=df_tanspose.rename(columns={0:'Mean_price'})

# %%
df_tanspose=df_tanspose.sort_values(by='Mean_price', ascending=False)

# %%
df_tanspose.head(15)
# Out:
#                       Mean_price
# Hackney                 4.346619
# Waltham Forest          4.323095
# Newham                  4.026703
# Lewisham                3.933575
# Barking & Dagenham      3.882201
# Haringey                3.802267
# Westminster             3.731357
# City of London          3.722374
# Inner London            3.645443
# Greenwich               3.593290
# Lambeth                 3.551997
# Southwark               3.543386
# Kensington & Chelsea    3.505897
# Islington               3.444060
# Merton                  3.434053

# %%
# Imported all the libraries
#imported dataset which is in excel format.
#cleaned all the data using predefined functions  and eliminated all the NaN values and filtered the information which were out of the required limits.
#processed data and found the top 15 Boroughs which prices increased more during the last two decades.
